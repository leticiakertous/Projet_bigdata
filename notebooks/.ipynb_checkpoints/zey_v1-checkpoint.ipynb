# %% [markdown]
# PROJET BIG DATA
#
# Sujet : Marché Immobilier
# Objectif : prédire le prix des biens
# source choisie
# colonnes qu’on veut extraire
# variable cible = prix
# variables explicatives = surface, ville, nombre de pièces, type de bien, description, etc.

# %% [markdown]
# choisssons SeLoger + Leboncoin car
# SeLoger:  Données propres et structurées
# Infos clés déjà prêtes :
# prix
# surface
# ville
# nombre de pièces
# Leboncoin: Énorme volume de données
# Descriptions réelles et non standardisées
# Idéal pour :
#  NLP (analyse de texte)
#  nettoyage avec Spark
#  suppression de bruit

# %% [markdown]
# les colonnes a recuperer:
#
# prix
# ville
# surface
# nb_pieces
# type_bien
# description
# source
