# %%
import requests
from bs4 import BeautifulSoup
import json, time, random, re
import pandas as pd

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"
}

annonces = []

villes = [
    ("paris", "g439"),
    ("lyon", "g69"),
    ("bordeaux", "g33"),
    ("marseille", "g13"),
    ("toulouse", "g31"),
    ("nantes", "g44"),
    ("nice", "g06"),
    ("lille", "g59"),
    ("montpellier", "g34"),
    ("rennes", "g35"),
]

types = ["ventes-appartements", "locations-appartements", "ventes-maisons", "locations-maisons"]

for type_bien in types:
    for ville_nom, ville_code in villes:
        for page in range(1, 16):
            url = f"https://www.pap.fr/annonce/{type_bien}-{ville_nom}-{ville_code}/p-{page}"
            try:
                r = requests.get(url, headers=headers, timeout=10)
                soup = BeautifulSoup(r.text, "html.parser")

                # Utiliser item-body comme conteneur principal
                cards = soup.select("div.item-body")
                if not cards:
                    print(f"  → Fin pour {type_bien}/{ville_nom} page {page}")
                    break

                for card in cards:
                    # Prix
                    prix_tag = card.select_one("span.item-price")
                    prix_text = prix_tag.get_text(strip=True) if prix_tag else ""
                    prix_match = re.search(r'([\d\s\.]+)', prix_text.replace('\xa0', ' '))
                    prix = prix_match.group(1).replace(" ", "").replace(".", "") if prix_match else ""

                    # Titre/localisation
                    titre_tag = card.select_one("a.item-title span.h1")
                    titre = titre_tag.get_text(strip=True) if titre_tag else ""

                    # Tags (surface, pièces)
                    tags = card.select("ul.item-tags li")
                    tags_text = [t.get_text(strip=True) for t in tags]

                    surface_match = next((re.search(r'([\d,]+)\s*m²', t) for t in tags_text if 'm²' in t), None)
                    surface = surface_match.group(1).replace(",", ".") if surface_match else ""

                    pieces_match = next((re.search(r'(\d+)\s*pièce', t) for t in tags_text if 'pièce' in t), None)
                    pieces = pieces_match.group(1) if pieces_match else ""

                    chambres_match = next((re.search(r'(\d+)\s*chambre', t) for t in tags_text if 'chambre' in t), None)
                    chambres = chambres_match.group(1) if chambres_match else ""

                    # Description
                    desc_tag = card.select_one("p.item-description")
                    description = desc_tag.get_text(strip=True) if desc_tag else ""

                    # On vérifie si le titre contient un code postal français (5 chiffres)
                    # Si ce n'est pas le cas, on passe à l'annonce suivante
                    cp_match = re.search(r'\((\d{5})\)', titre)
                    if not cp_match:
                        continue 
                    
                    # Optionnel : tu peux aussi créer une colonne CP propre
                    code_postal = cp_match.group(1)

                    if prix:
                        annonces.append({
                            "type": type_bien,
                            "ville": titre if titre else ville_nom,
                            "prix": prix,
                            "surface": surface,
                            "nb_pieces": pieces,
                            "nb_chambres": chambres,
                            "description": description,
                        })

                print(f"[{type_bien} - {ville_nom} - p.{page}] → {len(annonces)} annonces total")
                time.sleep(random.uniform(3, 7))

            except Exception as e:
                print(f"❌ Erreur : {e}")

# Sauvegarde
df = pd.DataFrame(annonces)

# Nettoyage rapide pour éviter les sauts de ligne dans les colonnes
df = df.replace(r'\n', ' ', regex=True).replace(r'\r', ' ', regex=True)
print(f"\n✅ {len(annonces)} annonces")
print(df.head())
print(df.isnull().sum())

df.to_csv("data/raw/scraping_pap.csv", 
          sep=";", 
          index=False, 
          encoding="utf-8-sig", 
          quoting=1) # Ajoute des guillemets pour protéger les textes longs
with open("data/raw/raw_pap.json", "w", encoding="utf-8") as f:
    json.dump(annonces, f, ensure_ascii=False, indent=2)
print("Fichiers sauvegardés !")
# Out:
# [ventes-appartements - paris - p.1] → 9 annonces total
# [ventes-appartements - paris - p.2] → 19 annonces total
# [ventes-appartements - paris - p.3] → 31 annonces total
# [ventes-appartements - paris - p.4] → 43 annonces total
# [ventes-appartements - paris - p.5] → 55 annonces total
# [ventes-appartements - paris - p.6] → 66 annonces total
# [ventes-appartements - paris - p.7] → 79 annonces total
# [ventes-appartements - paris - p.8] → 91 annonces total
# [ventes-appartements - paris - p.9] → 102 annonces total
# [ventes-appartements - paris - p.10] → 110 annonces total
# [ventes-appartements - paris - p.11] → 122 annonces total
# [ventes-appartements - paris - p.12] → 129 annonces total
# [ventes-appartements - paris - p.13] → 142 annonces total
# [ventes-appartements - paris - p.14] → 157 annonces total
# [ventes-appartements - paris - p.15] → 170 annonces total
# [ventes-appartements - lyon - p.1] → 170 annonces total
# [ventes-appartements - lyon - p.2] → 170 annonces total
# [ventes-appartements - lyon - p.3] → 170 annonces total
# [ventes-appartements - lyon - p.4] → 170 annonces total
# [ventes-appartements - lyon - p.5] → 170 annonces total
# [ventes-appartements - lyon - p.6] → 170 annonces total
# [ventes-appartements - lyon - p.7] → 170 annonces total
# [ventes-appartements - lyon - p.8] → 170 annonces total
# [ventes-appartements - lyon - p.9] → 170 annonces total
# [ventes-appartements - lyon - p.10] → 170 annonces total
# [ventes-appartements - lyon - p.11] → 170 annonces total
# [ventes-appartements - lyon - p.12] → 170 annonces total
# [ventes-appartements - lyon - p.13] → 170 annonces total
# [ventes-appartements - lyon - p.14] → 170 annonces total
# [ventes-appartements - lyon - p.15] → 170 annonces total
# [ventes-appartements - bordeaux - p.1] → 170 annonces total
# [ventes-appartements - bordeaux - p.2] → 170 annonces total
# [ventes-appartements - bordeaux - p.3] → 170 annonces total
# [ventes-appartements - bordeaux - p.4] → 170 annonces total
# [ventes-appartements - bordeaux - p.5] → 170 annonces total
# [ventes-appartements - bordeaux - p.6] → 170 annonces total
# [ventes-appartements - bordeaux - p.7] → 170 annonces total
# [ventes-appartements - bordeaux - p.8] → 170 annonces total
# [ventes-appartements - bordeaux - p.9] → 170 annonces total
# [ventes-appartements - bordeaux - p.10] → 170 annonces total
# [ventes-appartements - bordeaux - p.11] → 170 annonces total
# [ventes-appartements - bordeaux - p.12] → 170 annonces total
# [ventes-appartements - bordeaux - p.13] → 170 annonces total
# [ventes-appartements - bordeaux - p.14] → 170 annonces total
# [ventes-appartements - bordeaux - p.15] → 170 annonces total
# [ventes-appartements - marseille - p.1] → 170 annonces total
# [ventes-appartements - marseille - p.2] → 170 annonces total
# [ventes-appartements - marseille - p.3] → 170 annonces total
# [ventes-appartements - marseille - p.4] → 170 annonces total
# [ventes-appartements - marseille - p.5] → 170 annonces total
# [ventes-appartements - marseille - p.6] → 170 annonces total
# [ventes-appartements - marseille - p.7] → 170 annonces total
# [ventes-appartements - marseille - p.8] → 170 annonces total
# [ventes-appartements - marseille - p.9] → 170 annonces total
# [ventes-appartements - marseille - p.10] → 170 annonces total
# [ventes-appartements - marseille - p.11] → 170 annonces total
#   → Fin pour ventes-appartements/marseille page 12
# [ventes-appartements - toulouse - p.1] → 170 annonces total
# [ventes-appartements - toulouse - p.2] → 170 annonces total
# [ventes-appartements - toulouse - p.3] → 170 annonces total
# [ventes-appartements - toulouse - p.4] → 170 annonces total
# [ventes-appartements - toulouse - p.5] → 170 annonces total
# [ventes-appartements - toulouse - p.6] → 170 annonces total
# [ventes-appartements - toulouse - p.7] → 170 annonces total
# [ventes-appartements - toulouse - p.8] → 170 annonces total
# [ventes-appartements - toulouse - p.9] → 170 annonces total
# [ventes-appartements - toulouse - p.10] → 170 annonces total
# [ventes-appartements - toulouse - p.11] → 170 annonces total
# [ventes-appartements - toulouse - p.12] → 170 annonces total
# [ventes-appartements - toulouse - p.13] → 170 annonces total
# [ventes-appartements - toulouse - p.14] → 170 annonces total
# [ventes-appartements - toulouse - p.15] → 170 annonces total
# [ventes-appartements - nantes - p.1] → 170 annonces total
# [ventes-appartements - nantes - p.2] → 170 annonces total
# [ventes-appartements - nantes - p.3] → 170 annonces total
# [ventes-appartements - nantes - p.4] → 170 annonces total
# [ventes-appartements - nantes - p.5] → 170 annonces total
# [ventes-appartements - nantes - p.6] → 170 annonces total
# [ventes-appartements - nantes - p.7] → 170 annonces total
# [ventes-appartements - nantes - p.8] → 170 annonces total
# [ventes-appartements - nantes - p.9] → 170 annonces total
# [ventes-appartements - nantes - p.10] → 170 annonces total
# [ventes-appartements - nantes - p.11] → 170 annonces total
# [ventes-appartements - nantes - p.12] → 170 annonces total
# [ventes-appartements - nantes - p.13] → 170 annonces total
# [ventes-appartements - nantes - p.14] → 170 annonces total
# [ventes-appartements - nantes - p.15] → 170 annonces total
# [ventes-appartements - nice - p.1] → 180 annonces total
# [ventes-appartements - nice - p.2] → 191 annonces total
# [ventes-appartements - nice - p.3] → 201 annonces total
# [ventes-appartements - nice - p.4] → 211 annonces total
# [ventes-appartements - nice - p.5] → 218 annonces total
# [ventes-appartements - nice - p.6] → 229 annonces total
# [ventes-appartements - nice - p.7] → 240 annonces total
# [ventes-appartements - nice - p.8] → 251 annonces total
# [ventes-appartements - nice - p.9] → 264 annonces total
# [ventes-appartements - nice - p.10] → 277 annonces total
# [ventes-appartements - nice - p.11] → 291 annonces total
# [ventes-appartements - nice - p.12] → 305 annonces total
# [ventes-appartements - nice - p.13] → 318 annonces total
# [ventes-appartements - nice - p.14] → 332 annonces total
# [ventes-appartements - nice - p.15] → 347 annonces total
# [ventes-appartements - lille - p.1] → 347 annonces total
# [ventes-appartements - lille - p.2] → 347 annonces total
# [ventes-appartements - lille - p.3] → 347 annonces total
# [ventes-appartements - lille - p.4] → 347 annonces total
# [ventes-appartements - lille - p.5] → 347 annonces total
# [ventes-appartements - lille - p.6] → 347 annonces total
# [ventes-appartements - lille - p.7] → 347 annonces total
# [ventes-appartements - lille - p.8] → 347 annonces total
# [ventes-appartements - lille - p.9] → 347 annonces total
# [ventes-appartements - lille - p.10] → 347 annonces total
# [ventes-appartements - lille - p.11] → 347 annonces total
# [ventes-appartements - lille - p.12] → 347 annonces total
# [ventes-appartements - lille - p.13] → 347 annonces total
# [ventes-appartements - lille - p.14] → 347 annonces total
# [ventes-appartements - lille - p.15] → 347 annonces total
# [ventes-appartements - montpellier - p.1] → 348 annonces total
# [ventes-appartements - montpellier - p.2] → 352 annonces total
# [ventes-appartements - montpellier - p.3] → 354 annonces total
# [ventes-appartements - montpellier - p.4] → 355 annonces total
# [ventes-appartements - montpellier - p.5] → 356 annonces total
# [ventes-appartements - montpellier - p.6] → 357 annonces total
# [ventes-appartements - montpellier - p.7] → 358 annonces total
# [ventes-appartements - montpellier - p.8] → 359 annonces total
# [ventes-appartements - montpellier - p.9] → 360 annonces total
# [ventes-appartements - montpellier - p.10] → 361 annonces total
# [ventes-appartements - montpellier - p.11] → 362 annonces total
# [ventes-appartements - montpellier - p.12] → 363 annonces total
# [ventes-appartements - montpellier - p.13] → 364 annonces total
# [ventes-appartements - montpellier - p.14] → 365 annonces total
# [ventes-appartements - montpellier - p.15] → 366 annonces total
# [ventes-appartements - rennes - p.1] → 367 annonces total
# [ventes-appartements - rennes - p.2] → 368 annonces total
# [ventes-appartements - rennes - p.3] → 369 annonces total
# [ventes-appartements - rennes - p.4] → 370 annonces total
# [ventes-appartements - rennes - p.5] → 371 annonces total
# [ventes-appartements - rennes - p.6] → 372 annonces total
# [ventes-appartements - rennes - p.7] → 373 annonces total
# [ventes-appartements - rennes - p.8] → 374 annonces total
# [ventes-appartements - rennes - p.9] → 375 annonces total
# [ventes-appartements - rennes - p.10] → 376 annonces total
# [ventes-appartements - rennes - p.11] → 377 annonces total
# [ventes-appartements - rennes - p.12] → 378 annonces total
# [ventes-appartements - rennes - p.13] → 379 annonces total
# [ventes-appartements - rennes - p.14] → 380 annonces total
# [ventes-appartements - rennes - p.15] → 381 annonces total
# [locations-appartements - paris - p.1] → 387 annonces total
# [locations-appartements - paris - p.2] → 393 annonces total
# [locations-appartements - paris - p.3] → 405 annonces total
# [locations-appartements - paris - p.4] → 417 annonces total
# [locations-appartements - paris - p.5] → 430 annonces total
# [locations-appartements - paris - p.6] → 438 annonces total
# [locations-appartements - paris - p.7] → 448 annonces total
# [locations-appartements - paris - p.8] → 460 annonces total
# [locations-appartements - paris - p.9] → 471 annonces total
# [locations-appartements - paris - p.10] → 484 annonces total
# [locations-appartements - paris - p.11] → 493 annonces total
# [locations-appartements - paris - p.12] → 504 annonces total
# [locations-appartements - paris - p.13] → 513 annonces total
# [locations-appartements - paris - p.14] → 526 annonces total
# [locations-appartements - paris - p.15] → 534 annonces total
# [locations-appartements - lyon - p.1] → 534 annonces total
# [locations-appartements - lyon - p.2] → 534 annonces total
# [locations-appartements - lyon - p.3] → 534 annonces total
# [locations-appartements - lyon - p.4] → 534 annonces total
#   → Fin pour locations-appartements/lyon page 5
# [locations-appartements - bordeaux - p.1] → 534 annonces total
# [locations-appartements - bordeaux - p.2] → 534 annonces total
# [locations-appartements - bordeaux - p.3] → 534 annonces total
# [locations-appartements - bordeaux - p.4] → 534 annonces total
# [locations-appartements - bordeaux - p.5] → 534 annonces total
# [locations-appartements - bordeaux - p.6] → 534 annonces total
# [locations-appartements - bordeaux - p.7] → 534 annonces total
# [locations-appartements - bordeaux - p.8] → 534 annonces total
# [locations-appartements - bordeaux - p.9] → 534 annonces total
# [locations-appartements - bordeaux - p.10] → 534 annonces total
# [locations-appartements - bordeaux - p.11] → 534 annonces total
# [locations-appartements - bordeaux - p.12] → 534 annonces total
# [locations-appartements - bordeaux - p.13] → 534 annonces total
# [locations-appartements - bordeaux - p.14] → 534 annonces total
# [locations-appartements - bordeaux - p.15] → 534 annonces total
# [locations-appartements - marseille - p.1] → 534 annonces total
# [locations-appartements - marseille - p.2] → 534 annonces total
# [locations-appartements - marseille - p.3] → 534 annonces total
# [locations-appartements - marseille - p.4] → 534 annonces total
# [locations-appartements - marseille - p.5] → 534 annonces total
# [locations-appartements - marseille - p.6] → 534 annonces total
# [locations-appartements - marseille - p.7] → 534 annonces total
# [locations-appartements - marseille - p.8] → 534 annonces total
# [locations-appartements - marseille - p.9] → 534 annonces total
# [locations-appartements - marseille - p.10] → 534 annonces total
# [locations-appartements - marseille - p.11] → 534 annonces total
# [locations-appartements - marseille - p.12] → 534 annonces total
# [locations-appartements - marseille - p.13] → 534 annonces total
# [locations-appartements - marseille - p.14] → 534 annonces total
# [locations-appartements - marseille - p.15] → 534 annonces total
# [locations-appartements - toulouse - p.1] → 534 annonces total
# [locations-appartements - toulouse - p.2] → 534 annonces total
# [locations-appartements - toulouse - p.3] → 534 annonces total
# [locations-appartements - toulouse - p.4] → 534 annonces total
# [locations-appartements - toulouse - p.5] → 534 annonces total
# [locations-appartements - toulouse - p.6] → 534 annonces total
# [locations-appartements - toulouse - p.7] → 534 annonces total
# [locations-appartements - toulouse - p.8] → 534 annonces total
# [locations-appartements - toulouse - p.9] → 534 annonces total
# [locations-appartements - toulouse - p.10] → 534 annonces total
# [locations-appartements - toulouse - p.11] → 534 annonces total
# [locations-appartements - toulouse - p.12] → 534 annonces total
# [locations-appartements - toulouse - p.13] → 534 annonces total
# [locations-appartements - toulouse - p.14] → 534 annonces total
# [locations-appartements - toulouse - p.15] → 534 annonces total
# [locations-appartements - nantes - p.1] → 534 annonces total
# [locations-appartements - nantes - p.2] → 534 annonces total
# [locations-appartements - nantes - p.3] → 534 annonces total
# [locations-appartements - nantes - p.4] → 534 annonces total
# [locations-appartements - nantes - p.5] → 534 annonces total
# [locations-appartements - nantes - p.6] → 534 annonces total
# [locations-appartements - nantes - p.7] → 534 annonces total
# [locations-appartements - nantes - p.8] → 534 annonces total
# [locations-appartements - nantes - p.9] → 534 annonces total
# [locations-appartements - nantes - p.10] → 534 annonces total
# [locations-appartements - nantes - p.11] → 534 annonces total
# [locations-appartements - nantes - p.12] → 534 annonces total
# [locations-appartements - nantes - p.13] → 534 annonces total
# [locations-appartements - nantes - p.14] → 534 annonces total
# [locations-appartements - nantes - p.15] → 534 annonces total
# [locations-appartements - nice - p.1] → 540 annonces total
# [locations-appartements - nice - p.2] → 550 annonces total
# [locations-appartements - nice - p.3] → 561 annonces total
# [locations-appartements - nice - p.4] → 571 annonces total
# [locations-appartements - nice - p.5] → 579 annonces total
# [locations-appartements - nice - p.6] → 589 annonces total
# [locations-appartements - nice - p.7] → 602 annonces total
# [locations-appartements - nice - p.8] → 615 annonces total
# [locations-appartements - nice - p.9] → 628 annonces total
# [locations-appartements - nice - p.10] → 641 annonces total
# [locations-appartements - nice - p.11] → 656 annonces total
# [locations-appartements - nice - p.12] → 668 annonces total
# [locations-appartements - nice - p.13] → 681 annonces total
# [locations-appartements - nice - p.14] → 691 annonces total
# [locations-appartements - nice - p.15] → 706 annonces total
# [locations-appartements - lille - p.1] → 706 annonces total
# [locations-appartements - lille - p.2] → 706 annonces total
# [locations-appartements - lille - p.3] → 706 annonces total
# [locations-appartements - lille - p.4] → 706 annonces total
# [locations-appartements - lille - p.5] → 706 annonces total
# [locations-appartements - lille - p.6] → 706 annonces total
# [locations-appartements - lille - p.7] → 706 annonces total
# [locations-appartements - lille - p.8] → 706 annonces total
# [locations-appartements - lille - p.9] → 706 annonces total
# [locations-appartements - lille - p.10] → 706 annonces total
# [locations-appartements - lille - p.11] → 706 annonces total
# [locations-appartements - lille - p.12] → 706 annonces total
# [locations-appartements - lille - p.13] → 706 annonces total
# [locations-appartements - lille - p.14] → 706 annonces total
# [locations-appartements - lille - p.15] → 706 annonces total
# [locations-appartements - montpellier - p.1] → 715 annonces total
# [locations-appartements - montpellier - p.2] → 717 annonces total
#   → Fin pour locations-appartements/montpellier page 3
# [locations-appartements - rennes - p.1] → 717 annonces total
# [locations-appartements - rennes - p.2] → 717 annonces total
# [locations-appartements - rennes - p.3] → 717 annonces total
# [locations-appartements - rennes - p.4] → 717 annonces total
# [locations-appartements - rennes - p.5] → 717 annonces total
# [locations-appartements - rennes - p.6] → 717 annonces total
# [locations-appartements - rennes - p.7] → 717 annonces total
# [locations-appartements - rennes - p.8] → 717 annonces total
# [locations-appartements - rennes - p.9] → 717 annonces total
# [locations-appartements - rennes - p.10] → 717 annonces total
# [locations-appartements - rennes - p.11] → 717 annonces total
# [locations-appartements - rennes - p.12] → 717 annonces total
# [locations-appartements - rennes - p.13] → 717 annonces total
# [locations-appartements - rennes - p.14] → 717 annonces total
# [locations-appartements - rennes - p.15] → 717 annonces total
# [ventes-maisons - paris - p.1] → 726 annonces total
# [ventes-maisons - paris - p.2] → 735 annonces total
# [ventes-maisons - paris - p.3] → 747 annonces total
# [ventes-maisons - paris - p.4] → 759 annonces total
# [ventes-maisons - paris - p.5] → 771 annonces total
# [ventes-maisons - paris - p.6] → 777 annonces total
# [ventes-maisons - paris - p.7] → 789 annonces total
# [ventes-maisons - paris - p.8] → 801 annonces total
# [ventes-maisons - paris - p.9] → 813 annonces total
# [ventes-maisons - paris - p.10] → 825 annonces total
# [ventes-maisons - paris - p.11] → 837 annonces total
# [ventes-maisons - paris - p.12] → 849 annonces total
# [ventes-maisons - paris - p.13] → 861 annonces total
# [ventes-maisons - paris - p.14] → 873 annonces total
# [ventes-maisons - paris - p.15] → 885 annonces total
# [ventes-maisons - lyon - p.1] → 885 annonces total
# [ventes-maisons - lyon - p.2] → 885 annonces total
# [ventes-maisons - lyon - p.3] → 885 annonces total
# [ventes-maisons - lyon - p.4] → 885 annonces total
# [ventes-maisons - lyon - p.5] → 885 annonces total
# [ventes-maisons - lyon - p.6] → 885 annonces total
# [ventes-maisons - lyon - p.7] → 885 annonces total
# [ventes-maisons - lyon - p.8] → 885 annonces total
# [ventes-maisons - lyon - p.9] → 885 annonces total
# [ventes-maisons - lyon - p.10] → 885 annonces total
# [ventes-maisons - lyon - p.11] → 885 annonces total
# [ventes-maisons - lyon - p.12] → 885 annonces total
# [ventes-maisons - lyon - p.13] → 885 annonces total
# [ventes-maisons - lyon - p.14] → 885 annonces total
# [ventes-maisons - lyon - p.15] → 885 annonces total
# [ventes-maisons - bordeaux - p.1] → 885 annonces total
# [ventes-maisons - bordeaux - p.2] → 885 annonces total
# [ventes-maisons - bordeaux - p.3] → 885 annonces total
# [ventes-maisons - bordeaux - p.4] → 885 annonces total
# [ventes-maisons - bordeaux - p.5] → 885 annonces total
# [ventes-maisons - bordeaux - p.6] → 885 annonces total
# [ventes-maisons - bordeaux - p.7] → 885 annonces total
# [ventes-maisons - bordeaux - p.8] → 885 annonces total
# [ventes-maisons - bordeaux - p.9] → 885 annonces total
# [ventes-maisons - bordeaux - p.10] → 885 annonces total
# [ventes-maisons - bordeaux - p.11] → 885 annonces total
# [ventes-maisons - bordeaux - p.12] → 885 annonces total
# [ventes-maisons - bordeaux - p.13] → 885 annonces total
# [ventes-maisons - bordeaux - p.14] → 885 annonces total
# [ventes-maisons - bordeaux - p.15] → 885 annonces total
# [ventes-maisons - marseille - p.1] → 885 annonces total
# [ventes-maisons - marseille - p.2] → 885 annonces total
# [ventes-maisons - marseille - p.3] → 885 annonces total
# [ventes-maisons - marseille - p.4] → 885 annonces total
# [ventes-maisons - marseille - p.5] → 885 annonces total
# [ventes-maisons - marseille - p.6] → 885 annonces total
# [ventes-maisons - marseille - p.7] → 885 annonces total
# [ventes-maisons - marseille - p.8] → 885 annonces total
# [ventes-maisons - marseille - p.9] → 885 annonces total
# [ventes-maisons - marseille - p.10] → 885 annonces total
# [ventes-maisons - marseille - p.11] → 885 annonces total
# [ventes-maisons - marseille - p.12] → 885 annonces total
# [ventes-maisons - marseille - p.13] → 885 annonces total
# [ventes-maisons - marseille - p.14] → 885 annonces total
# [ventes-maisons - marseille - p.15] → 885 annonces total
# [ventes-maisons - toulouse - p.1] → 885 annonces total
# [ventes-maisons - toulouse - p.2] → 885 annonces total
# [ventes-maisons - toulouse - p.3] → 885 annonces total
# [ventes-maisons - toulouse - p.4] → 885 annonces total
# [ventes-maisons - toulouse - p.5] → 885 annonces total
# [ventes-maisons - toulouse - p.6] → 885 annonces total
# [ventes-maisons - toulouse - p.7] → 885 annonces total
# [ventes-maisons - toulouse - p.8] → 885 annonces total
# [ventes-maisons - toulouse - p.9] → 885 annonces total
# [ventes-maisons - toulouse - p.10] → 885 annonces total
# [ventes-maisons - toulouse - p.11] → 885 annonces total
# [ventes-maisons - toulouse - p.12] → 885 annonces total
# [ventes-maisons - toulouse - p.13] → 885 annonces total
# [ventes-maisons - toulouse - p.14] → 885 annonces total
# [ventes-maisons - toulouse - p.15] → 885 annonces total
# [ventes-maisons - nantes - p.1] → 885 annonces total
# [ventes-maisons - nantes - p.2] → 885 annonces total
# [ventes-maisons - nantes - p.3] → 885 annonces total
# [ventes-maisons - nantes - p.4] → 885 annonces total
# [ventes-maisons - nantes - p.5] → 885 annonces total
# [ventes-maisons - nantes - p.6] → 885 annonces total
# [ventes-maisons - nantes - p.7] → 885 annonces total
# [ventes-maisons - nantes - p.8] → 885 annonces total
# [ventes-maisons - nantes - p.9] → 885 annonces total
# [ventes-maisons - nantes - p.10] → 885 annonces total
# [ventes-maisons - nantes - p.11] → 885 annonces total
# [ventes-maisons - nantes - p.12] → 885 annonces total
# [ventes-maisons - nantes - p.13] → 885 annonces total
# [ventes-maisons - nantes - p.14] → 885 annonces total
# [ventes-maisons - nantes - p.15] → 885 annonces total
# [ventes-maisons - nice - p.1] → 896 annonces total
# [ventes-maisons - nice - p.2] → 901 annonces total
# [ventes-maisons - nice - p.3] → 911 annonces total
# [ventes-maisons - nice - p.4] → 922 annonces total
#   → Fin pour ventes-maisons/nice page 5
# [ventes-maisons - lille - p.1] → 922 annonces total
# [ventes-maisons - lille - p.2] → 922 annonces total
# [ventes-maisons - lille - p.3] → 922 annonces total
# [ventes-maisons - lille - p.4] → 922 annonces total
# [ventes-maisons - lille - p.5] → 922 annonces total
# [ventes-maisons - lille - p.6] → 922 annonces total
# [ventes-maisons - lille - p.7] → 922 annonces total
# [ventes-maisons - lille - p.8] → 922 annonces total
# [ventes-maisons - lille - p.9] → 922 annonces total
# [ventes-maisons - lille - p.10] → 922 annonces total
# [ventes-maisons - lille - p.11] → 922 annonces total
# [ventes-maisons - lille - p.12] → 922 annonces total
# [ventes-maisons - lille - p.13] → 922 annonces total
# [ventes-maisons - lille - p.14] → 922 annonces total
# [ventes-maisons - lille - p.15] → 922 annonces total
# [ventes-maisons - montpellier - p.1] → 927 annonces total
# [ventes-maisons - montpellier - p.2] → 929 annonces total
# [ventes-maisons - montpellier - p.3] → 931 annonces total
# [ventes-maisons - montpellier - p.4] → 933 annonces total
# [ventes-maisons - montpellier - p.5] → 935 annonces total
# [ventes-maisons - montpellier - p.6] → 938 annonces total
# [ventes-maisons - montpellier - p.7] → 943 annonces total
# [ventes-maisons - montpellier - p.8] → 948 annonces total
# [ventes-maisons - montpellier - p.9] → 954 annonces total
# [ventes-maisons - montpellier - p.10] → 958 annonces total
# [ventes-maisons - montpellier - p.11] → 962 annonces total
# [ventes-maisons - montpellier - p.12] → 968 annonces total
# [ventes-maisons - montpellier - p.13] → 973 annonces total
# [ventes-maisons - montpellier - p.14] → 977 annonces total
# [ventes-maisons - montpellier - p.15] → 983 annonces total
# [ventes-maisons - rennes - p.1] → 984 annonces total
# [ventes-maisons - rennes - p.2] → 985 annonces total
# [ventes-maisons - rennes - p.3] → 986 annonces total
# [ventes-maisons - rennes - p.4] → 987 annonces total
# [ventes-maisons - rennes - p.5] → 988 annonces total
# [ventes-maisons - rennes - p.6] → 989 annonces total
# [ventes-maisons - rennes - p.7] → 990 annonces total
# [ventes-maisons - rennes - p.8] → 991 annonces total
# [ventes-maisons - rennes - p.9] → 992 annonces total
# [ventes-maisons - rennes - p.10] → 993 annonces total
# [ventes-maisons - rennes - p.11] → 994 annonces total
# [ventes-maisons - rennes - p.12] → 995 annonces total
# [ventes-maisons - rennes - p.13] → 996 annonces total
#   → Fin pour ventes-maisons/rennes page 14
# [locations-maisons - paris - p.1] → 998 annonces total
# [locations-maisons - paris - p.2] → 1000 annonces total
# [locations-maisons - paris - p.3] → 1002 annonces total
# [locations-maisons - paris - p.4] → 1004 annonces total
# [locations-maisons - paris - p.5] → 1006 annonces total
# [locations-maisons - paris - p.6] → 1008 annonces total
# [locations-maisons - paris - p.7] → 1010 annonces total
# [locations-maisons - paris - p.8] → 1012 annonces total
# [locations-maisons - paris - p.9] → 1014 annonces total
# [locations-maisons - paris - p.10] → 1016 annonces total
# [locations-maisons - paris - p.11] → 1018 annonces total
# [locations-maisons - paris - p.12] → 1020 annonces total
# [locations-maisons - paris - p.13] → 1022 annonces total
# [locations-maisons - paris - p.14] → 1024 annonces total
# [locations-maisons - paris - p.15] → 1026 annonces total
# [locations-maisons - lyon - p.1] → 1026 annonces total
# [locations-maisons - lyon - p.2] → 1026 annonces total
# [locations-maisons - lyon - p.3] → 1026 annonces total
# [locations-maisons - lyon - p.4] → 1026 annonces total
# [locations-maisons - lyon - p.5] → 1026 annonces total
# [locations-maisons - lyon - p.6] → 1026 annonces total
# [locations-maisons - lyon - p.7] → 1026 annonces total
# [locations-maisons - lyon - p.8] → 1026 annonces total
# [locations-maisons - lyon - p.9] → 1026 annonces total
# [locations-maisons - lyon - p.10] → 1026 annonces total
# [locations-maisons - lyon - p.11] → 1026 annonces total
# [locations-maisons - lyon - p.12] → 1026 annonces total
# [locations-maisons - lyon - p.13] → 1026 annonces total
# [locations-maisons - lyon - p.14] → 1026 annonces total
# [locations-maisons - lyon - p.15] → 1026 annonces total
# [locations-maisons - bordeaux - p.1] → 1026 annonces total
# [locations-maisons - bordeaux - p.2] → 1026 annonces total
# [locations-maisons - bordeaux - p.3] → 1026 annonces total
# [locations-maisons - bordeaux - p.4] → 1026 annonces total
# [locations-maisons - bordeaux - p.5] → 1026 annonces total
# [locations-maisons - bordeaux - p.6] → 1026 annonces total
# [locations-maisons - bordeaux - p.7] → 1026 annonces total
# [locations-maisons - bordeaux - p.8] → 1026 annonces total
# [locations-maisons - bordeaux - p.9] → 1026 annonces total
# [locations-maisons - bordeaux - p.10] → 1026 annonces total
# [locations-maisons - bordeaux - p.11] → 1026 annonces total
# [locations-maisons - bordeaux - p.12] → 1026 annonces total
# [locations-maisons - bordeaux - p.13] → 1026 annonces total
#   → Fin pour locations-maisons/bordeaux page 14
# [locations-maisons - marseille - p.1] → 1026 annonces total
# [locations-maisons - marseille - p.2] → 1026 annonces total
# [locations-maisons - marseille - p.3] → 1026 annonces total
# [locations-maisons - marseille - p.4] → 1026 annonces total
# [locations-maisons - marseille - p.5] → 1026 annonces total
# [locations-maisons - marseille - p.6] → 1026 annonces total
# [locations-maisons - marseille - p.7] → 1026 annonces total
# [locations-maisons - marseille - p.8] → 1026 annonces total
# [locations-maisons - marseille - p.9] → 1026 annonces total
# [locations-maisons - marseille - p.10] → 1026 annonces total
# [locations-maisons - marseille - p.11] → 1026 annonces total
# [locations-maisons - marseille - p.12] → 1026 annonces total
# [locations-maisons - marseille - p.13] → 1026 annonces total
# [locations-maisons - marseille - p.14] → 1026 annonces total
# [locations-maisons - marseille - p.15] → 1026 annonces total
# [locations-maisons - toulouse - p.1] → 1026 annonces total
# [locations-maisons - toulouse - p.2] → 1026 annonces total
# [locations-maisons - toulouse - p.3] → 1026 annonces total
# [locations-maisons - toulouse - p.4] → 1026 annonces total
# [locations-maisons - toulouse - p.5] → 1026 annonces total
# [locations-maisons - toulouse - p.6] → 1026 annonces total
# [locations-maisons - toulouse - p.7] → 1026 annonces total
# [locations-maisons - toulouse - p.8] → 1026 annonces total
# [locations-maisons - toulouse - p.9] → 1026 annonces total
# [locations-maisons - toulouse - p.10] → 1026 annonces total
# [locations-maisons - toulouse - p.11] → 1026 annonces total
# [locations-maisons - toulouse - p.12] → 1026 annonces total
# [locations-maisons - toulouse - p.13] → 1026 annonces total
# [locations-maisons - toulouse - p.14] → 1026 annonces total
# [locations-maisons - toulouse - p.15] → 1026 annonces total
# [locations-maisons - nantes - p.1] → 1026 annonces total
# [locations-maisons - nantes - p.2] → 1026 annonces total
# [locations-maisons - nantes - p.3] → 1026 annonces total
# [locations-maisons - nantes - p.4] → 1026 annonces total
# [locations-maisons - nantes - p.5] → 1026 annonces total
# [locations-maisons - nantes - p.6] → 1026 annonces total
# [locations-maisons - nantes - p.7] → 1026 annonces total
# [locations-maisons - nantes - p.8] → 1026 annonces total
# [locations-maisons - nantes - p.9] → 1026 annonces total
# [locations-maisons - nantes - p.10] → 1026 annonces total
# [locations-maisons - nantes - p.11] → 1026 annonces total
# [locations-maisons - nantes - p.12] → 1026 annonces total
# [locations-maisons - nantes - p.13] → 1026 annonces total
# [locations-maisons - nantes - p.14] → 1026 annonces total
# [locations-maisons - nantes - p.15] → 1026 annonces total
# [locations-maisons - nice - p.1] → 1035 annonces total
# [locations-maisons - nice - p.2] → 1045 annonces total
# [locations-maisons - nice - p.3] → 1058 annonces total
# [locations-maisons - nice - p.4] → 1070 annonces total
# [locations-maisons - nice - p.5] → 1083 annonces total
# [locations-maisons - nice - p.6] → 1094 annonces total
# [locations-maisons - nice - p.7] → 1109 annonces total
# [locations-maisons - nice - p.8] → 1124 annonces total
# [locations-maisons - nice - p.9] → 1137 annonces total
# [locations-maisons - nice - p.10] → 1152 annonces total
# [locations-maisons - nice - p.11] → 1166 annonces total
# [locations-maisons - nice - p.12] → 1180 annonces total
# [locations-maisons - nice - p.13] → 1193 annonces total
# [locations-maisons - nice - p.14] → 1204 annonces total
# [locations-maisons - nice - p.15] → 1218 annonces total
# [locations-maisons - lille - p.1] → 1218 annonces total
# [locations-maisons - lille - p.2] → 1218 annonces total
# [locations-maisons - lille - p.3] → 1218 annonces total
# [locations-maisons - lille - p.4] → 1218 annonces total
# [locations-maisons - lille - p.5] → 1218 annonces total
# [locations-maisons - lille - p.6] → 1218 annonces total
# [locations-maisons - lille - p.7] → 1218 annonces total
# [locations-maisons - lille - p.8] → 1218 annonces total
# [locations-maisons - lille - p.9] → 1218 annonces total
# [locations-maisons - lille - p.10] → 1218 annonces total
# [locations-maisons - lille - p.11] → 1218 annonces total
# [locations-maisons - lille - p.12] → 1218 annonces total
# [locations-maisons - lille - p.13] → 1218 annonces total
# [locations-maisons - lille - p.14] → 1218 annonces total
# [locations-maisons - lille - p.15] → 1218 annonces total
# [locations-maisons - montpellier - p.1] → 1221 annonces total
#   → Fin pour locations-maisons/montpellier page 2
# [locations-maisons - rennes - p.1] → 1221 annonces total
# [locations-maisons - rennes - p.2] → 1221 annonces total
# [locations-maisons - rennes - p.3] → 1221 annonces total
# [locations-maisons - rennes - p.4] → 1221 annonces total
# [locations-maisons - rennes - p.5] → 1221 annonces total
# [locations-maisons - rennes - p.6] → 1221 annonces total
# [locations-maisons - rennes - p.7] → 1221 annonces total
# [locations-maisons - rennes - p.8] → 1221 annonces total
# [locations-maisons - rennes - p.9] → 1221 annonces total
# [locations-maisons - rennes - p.10] → 1221 annonces total
# [locations-maisons - rennes - p.11] → 1221 annonces total
# [locations-maisons - rennes - p.12] → 1221 annonces total
# [locations-maisons - rennes - p.13] → 1221 annonces total
# [locations-maisons - rennes - p.14] → 1221 annonces total
# [locations-maisons - rennes - p.15] → 1221 annonces total
#
# ✅ 1221 annonces
#                   type              ville     prix surface nb_pieces  \
# 0  ventes-appartements   Paris 5E (75005)   390000      31         2
# 1  ventes-appartements   Paris 2E (75002)   770000      64         2
# 2  ventes-appartements   Paris 5E (75005)  1090000  107.40         4
# 3  ventes-appartements  Paris 10E (75010)   630000      60         3
# 4  ventes-appartements   Paris 7E (75007)   425000      30         2
#
#   nb_chambres                                        description
# 0           1  Très bien situé, tout commerces au pied de l'i...
# 1           1  **Très bel appartement traversant** situé au 5...
# 2           3  **Grand duplex de charme quartier Gobelins Jar...
# 3           1  Appartement 3 pièces 60 m2, proche Place Franz...
# 4           1  Appartement de 30 m² situé au rez-de-chaussée ...
# type           0
# ville          0
# prix           0
# surface        0
# nb_pieces      0
# nb_chambres    0
# description    0
# dtype: int64
# Fichiers sauvegardés !
